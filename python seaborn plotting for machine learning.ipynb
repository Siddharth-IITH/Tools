# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
data=sns.load_dataset('flights')

# %%
data.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
# year          144 non-null int64
# month         144 non-null category
# passengers    144 non-null int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
data.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.relplot(x="passengers",y="month",hue="year",data=data)

# %%
data_b=sns.load_dataset('tips')

# %%
data_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
sns.relplot(x='time',y='tip',data=data_b, kind="line")

# %%
sns.catplot(x='day',y='total_bill',data=data_b)

# %%
sns.catplot(x='day',y='total_bill',data=data_b, kind = "swarm")

# %%
sns.catplot(x='day',y='total_bill',data=data_b, kind = "violin")

# %%
sns.catplot(x='day',y='total_bill',data=data_b, kind = "box")

# %%
sns.catplot(x='day',y='total_bill',data=data_b, kind = "boxen")

# %%
data_c=np.random.normal(loc=5,size=100,scale=2)

# %%
sns.distplot(data_c)

# %%
data_iris=sns.load_dataset("iris")
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data_p=sns.FacetGrid(data_iris,col='species',hue='species')
data_p.map(plt.hist,'sepal_length')

# %%
data_p=sns.FacetGrid(data_iris,col='species',hue='species')
data_p.map(plt.hist,'sepal_width')

# %%
sns.set_palette('husl')
# sns.set(style='darkgrid')
data_pair=sns.PairGrid(data_iris,hue='species')
data_pair.map(plt.scatter)

# %%
sns.catplot(data=data_iris, kind = "boxen")

# %%
sns.catplot(x='sepal_length',y='petal_length',data=data_iris,hue='species', kind = "swarm")

# %%
sns.relplot(x='sepal_length',y='petal_length',data=data_iris,hue='species',kind='line')

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=data_iris,hue='species',kind='line')

# %%
sns.catplot(x='sepal_length',y='species',data=data_iris,hue='species', kind = "violin")

# %%
sns.catplot(x='sepal_length',y='species',data=data_iris,hue='species', kind = "boxen")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.catplot(x='sepal_length',y='species',data=data_iris,hue='species', kind = "box")

# %%
sns.set(style='white',color_codes=True)
sns.boxplot(x='sepal_length',y='species',data=data_iris,hue='species')

# %%
data_tips=sns.load_dataset("tips")
sns.set(style='white',color_codes=True)
sns.boxplot(x='day',y='total_bill',data=data_tips)
sns.despine(offset=10, trim=True)

# %%
c=sns.color_palette()
sns.palplot(c)
